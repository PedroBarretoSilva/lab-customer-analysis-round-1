# %% [markdown]
# # Customer Analysis Round 1

# %%
import pandas as pd
import numpy as np

# %%
file1=pd.read_csv("file1.csv")
file2=pd.read_csv("file2.csv")
file3=pd.read_csv("file3.csv")

# %%
# Show the DataFrame's shape :

# %%
file1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
file3.shape
# Out:
# (7070, 11)

# %%
# Standardize header names.

# The the column State  exists in several tables but its description is not the same

# %%
file3 = file3.rename(columns={'State':'ST'})
file3
# Out:
#      Customer          ST  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
# Concatenate the three dataframes

# %%
data = pd.concat([file1, file2, file3], axis=0) 
data.shape
data
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California    NaN              Bachelor
# 7066  PK87824  California    NaN               College
# 7067  TD14365  California    NaN              Bachelor
# 7068  UP19263  California    NaN               College
# 7069  Y167826  California    NaN               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# Which columns are numerical?

data._get_numeric_data()
# Out:
#        Income  Monthly Premium Auto  Total Claim Amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
# Which columns are categorical?

data.select_dtypes("object")
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California    NaN              Bachelor
# 7066  PK87824  California    NaN               College
# 7067  TD14365  California    NaN              Bachelor
# 7068  UP19263  California    NaN               College
# 7069  Y167826  California    NaN               College
#
#      Customer Lifetime Value Number of Open Complaints     Policy Type  \
# 0                        NaN                    1/0/00   Personal Auto
# 1                 697953.59%                    1/0/00   Personal Auto
# 2                1288743.17%                    1/0/00   Personal Auto
# ...

# %% [markdown]
# # Datacleaning

# %%
# Delete the column education and the number of open complaints from the dataframe.

# %%
data = data.drop(['Education', 'Number of Open Complaints'], axis=1)
data
# Out:
#      Customer          ST GENDER Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California    NaN             23405.98798  71941.0
# 7066  PK87824  California    NaN             3096.511217  21604.0
# 7067  TD14365  California    NaN             8163.890428      0.0
# 7068  UP19263  California    NaN             7524.442436  21941.0
# 7069  Y167826  California    NaN             2611.836866      0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
# Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change
# dtype to numerical type.

# %%
data['Customer Lifetime Value'] = data['Customer Lifetime Value'].astype('str')
data['Customer Lifetime Value'] = data['Customer Lifetime Value'].apply(lambda x: x.replace('%', ''))
data['Customer Lifetime Value'] = data['Customer Lifetime Value'].astype('float')

# %%
data['Customer Lifetime Value'] = data['Customer Lifetime Value'] / 10000
data.head()
# Out:
#   Customer          ST GENDER  Customer Lifetime Value   Income  \
# 0  RB50392  Washington    NaN                      NaN      0.0
# 1  QZ44356     Arizona      F                69.795359      0.0
# 2  AI49188      Nevada      F               128.874317  48767.0
# 3  WW63253  California      M                76.458618      0.0
# 4  GA49547  Washington      M                53.630765  36357.0
#
#    Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323
#
#   Gender
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
# Check for duplicate rows in the data and remove if any.

# %%
data = data.drop_duplicates()

# checking there are no duplicates lefting :
data.duplicated().sum()
# Out:
# 0

# %%
# Filter out the data for customers who have an income of 0 or less.
data = data[data.Income <= 0] 
data.head()
# Out:
#    Customer          ST GENDER  Customer Lifetime Value  Income  \
# 0   RB50392  Washington    NaN                      NaN     0.0
# 1   QZ44356     Arizona      F                69.795359     0.0
# 3   WW63253  California      M                76.458618     0.0
# 7   CF85061     Arizona      M                72.161003     0.0
# 10  SX51350  California      M                47.389920     0.0
#
#     Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                 1000.0   Personal Auto  Four-Door Car            2.704934
# 1                   94.0   Personal Auto  Four-Door Car         1131.464935
# 3                  106.0  Corporate Auto            SUV          529.881344
# 7                  101.0  Corporate Auto  Four-Door Car          363.029680
# 10                  67.0   Personal Auto  Four-Door Car          482.400000
#
#    Gender
# 0     NaN
# 1     NaN
# 3     NaN
# 7     NaN
# 10    NaN
